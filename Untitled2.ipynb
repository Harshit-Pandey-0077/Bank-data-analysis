# %%
import pandas as pd

# %%
df = pd .read_excel("D:\projects internship\Gncipl\proccessed data .xlsx")

# %%
df.head()
# Out:
#         author       date    address       bank  rating review_title_by_user  \
# 0  AMRENDRA  T 2020-03-21  New delhi        SBI     4.0          Best saving
# 1       BISHWA 2020-03-20    Kolkata        SBI     5.0         Good service
# 2      SANTOSH 2020-03-20    Hooghly  Axis Bank     5.0    Excellent Service
# 3      MAHADEV 2020-03-20       Pune  HDFC Bank     5.0    Excellent service
# 4           MD 2020-03-20  Hyderabad       IDBI     5.0                Good
#
#                                               review  \
# 0  State Bank Of India is located nearby in our a...
# 1  I have my salary account in SBI, when I applie...
# 2  I am using Axis bank saving account for the  p...
# 3  I have my salary bank account in HDFC bank for...
# 4  I am not getting an alert message from IDBI ba...
#
#                                           bank_image rating_title_by_user  \
# 0  https://static.bankbazaar.com/images/common/ba...               Great!
# ...

# %%
df.tail()
# Out:
#         author       date    address                  bank  rating  \
# 710    ANONYMS 2019-11-26  Bangalore                   SBI     4.0
# 711          M 2019-11-26  Bangalore  Punjab National Bank     4.0
# 712        A L 2019-11-26  Ernakulam             Axis Bank     4.0
# 713    ANONYMS 2019-11-26  Bangalore             Axis Bank     4.0
# 714  SAJJANOJU 2019-11-26  Hyderabad             Axis Bank     5.0
#
#          review_title_by_user  \
# 710    Process has to be fast
# 711                     Good
# 712        Mobile app is good
# 713  Unhappy with the charges
# 714                 Good Bank
#
#                                                 review  \
# 710  If any account to be activated in SBI, they ar...
# 711  I am holding a savings account with PUNJAB NAT...
# 712  There is no mandatory balance to keep in my Ax...
# 713  In Axis bank, every month they are charging me...
# 714  I have a salary account with AXIS bank and I h...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 715 entries, 0 to 714
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   author                713 non-null    object
#  1   date                  715 non-null    datetime64[ns]
#  2   address               715 non-null    object
#  3   bank                  715 non-null    object
#  4   rating                715 non-null    float64
#  5   review_title_by_user  715 non-null    object
#  6   review                715 non-null    object
#  7   bank_image            715 non-null    object
#  8   rating_title_by_user  715 non-null    object
#  9   useful_count          715 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 56.0+ KB

# %%
avg_rating = df.groupby("bank")["rating"].mean().reset_index().sort_values("rating", ascending=False)
print(avg_rating)
# Out:
#                    bank    rating
# 2              Citibank  4.714286
# 7  Punjab National Bank  4.535714
# 3             HDFC Bank  4.484043
# 0             Axis Bank  4.393130
# 6                 Kotak  4.318750
# 4                  IDBI  4.285714
# 8                   SBI  4.280822
# 1           Canara Bank  4.257143
# 5         IndusInd Bank  4.225000

# %%
review_counts = df["bank"].value_counts()
print(review_counts)
# Out:
# bank
# SBI                     219
# HDFC Bank               188
# Axis Bank               131
# Kotak                    80
# Canara Bank              35
# IndusInd Bank            20
# IDBI                     14
# Citibank                 14
# Punjab National Bank     14
# Name: count, dtype: int64

# %%
top_useful = df.sort_values("useful_count", ascending=False).head(10)[["author", "bank", "rating", "review_title_by_user", "useful_count"]]
print(top_useful)
# Out:
#          author       bank  rating        review_title_by_user  useful_count
# 0   AMRENDRA  T        SBI     4.0                 Best saving           133
# 1        BISHWA        SBI     5.0                Good service            89
# 3       MAHADEV  HDFC Bank     5.0           Excellent service            52
# 5    DINESH K V        SBI     4.0                Good account            52
# 2       SANTOSH  Axis Bank     5.0           Excellent Service            48
# 6             D      Kotak     5.0                Good service            44
# 10           AK        SBI     5.0                       Great            43
# 12            V        SBI     4.0  Need to improve in service            41
# 4            MD       IDBI     5.0                       Good             37
# 7             N  HDFC Bank     5.0                        Good            35

# %%
print(df["rating"].mean())
# Out:
# 4.36993006993007
